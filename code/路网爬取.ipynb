# %%
import osmnx as ox
import networkx as nx
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# %%
#获取范围内的路网信息
G = ox.graph_from_bbox(22.946181280734507,22.887937136605547,113.29484041365231 ,113.36412360410134,network_type='drive')
G
# Out:
# /var/folders/2z/f8z513gx01z7mc4x4jwlp5j00000gn/T/ipykernel_1121/46801509.py:2: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   G = ox.graph_from_bbox(22.946181280734507,22.887937136605547,113.29484041365231 ,113.36412360410134,network_type='drive')

# %%
#投影
G_proj = ox.project_graph(G)
ox.plot_graph(G_proj)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
ox.save_graph_shapefile(G_proj,'大沙路.shp')
# Out:
# /var/folders/2z/f8z513gx01z7mc4x4jwlp5j00000gn/T/ipykernel_1121/3814256935.py:1: FutureWarning: The `save_graph_shapefile` function is deprecated and will be removed in the v2.0.0 release. Instead, use the `save_graph_geopackage` function to save graphs as GeoPackage files for subsequent GIS analysis. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   ox.save_graph_shapefile(G_proj,'大沙路.shp')
# /Users/buxiangzun/anaconda3/lib/python3.11/site-packages/osmnx/io.py:115: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_nodes.to_file(filepath_nodes, driver="ESRI Shapefile", index=True, encoding=encoding)
# /Users/buxiangzun/anaconda3/lib/python3.11/site-packages/pyogrio/raw.py:709: RuntimeWarning: Normalized/laundered field name: 'street_count' to 'street_cou'
#   ogr_write(

# %%
import gotrackit.netreverse.NetGen as ng

# %%
# 必须要指定:
#1.左下角点的经纬度坐标，矩形区域的宽度和高度
# 2.key_list
# 3:输出路网的存储文件目录net out_fldr
# 4.请求的路径源文件的存储文件目录binary_path_fldr,
# 5:平面投影坐标系 plain_crs
# 6.od type='rand od'
nv = ng.NetReverse(flag_name='sh',
                   net_out_fldr=r'/Users/buxiangzun/Desktop/BusNetPy/',
                   plain_crs='EPSG:32651', save_tpr_link=True, angle_threshold=30)
nv.generate_net_from_request(key_list=['084766d8a931ae60ef200ac9140a26d4'],
                             log_fldr=r'./',save_log_file=False,
                             binary_path_fldr=r'/Users/buxiangzun/Desktop/BusNetPy/', od_type='rand_od',
                             cache_times=300,od_num=100,
                             w=2000,h=2000,min_lng=113.334434, min_lat=22.928064, min_od_length=200, gap_n=200,
                             ignore_hh=True, boundary_buffer=1000)
# Out:
# sh 生成OD......
# [07/16/2024 11:40:04 INFO] sh_logging_info:.....
# [07/16/2024 11:40:04 INFO] 请求sh, 第5个文件...
# [07/16/2024 11:40:04 INFO] already_request_list_len: 0
# [07/16/2024 11:40:04 INFO] 尚且未请求的有100条
# [07/16/2024 11:40:04 INFO] 在11时段内的有:100条
# [07/16/2024 11:40:04 INFO] Success - od: 1, info_code: 10000, Request Success, count: 0.
# [07/16/2024 11:40:04 INFO] Success - od: 2, info_code: 10000, Request Success, count: 1.
# [07/16/2024 11:40:04 INFO] Success - od: 3, info_code: 10000, Request Success, count: 2.
# [07/16/2024 11:40:04 INFO] Success - od: 4, info_code: 10000, Request Success, count: 3.
# [07/16/2024 11:40:05 INFO] Success - od: 5, info_code: 10000, Request Success, count: 4.
# [07/16/2024 11:40:05 INFO] Success - od: 6, info_code: 10000, Request Success, count: 5.
# [07/16/2024 11:40:05 INFO] Success - od: 7, info_code: 10000, Request Success, count: 6.
# [07/16/2024 11:40:05 INFO] Success - od: 8, info_code: 10000, Request Success, count: 7.
# ...
